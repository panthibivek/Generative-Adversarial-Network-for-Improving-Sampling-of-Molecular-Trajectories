# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
dirname = "/home/panthibivek/thesis/config_files_orca/calculate_energies.txt"
energies = []
with open(dirname, 'r') as f:
    energies = [float(line.strip()) for line in f if line]
energies = np.array(energies)
print("output data size:", energies.shape)
# Out:
# output data size: (1000,)

# %%
from scipy import stats
plt.figure(figsize=(7,7))
plt.hist(energies, bins=30, color="lightblue", align='left', rwidth=0.9)
plt.xlabel('Bins', fontsize=15)
plt.ylabel('Count', fontsize=15)
fig1 = plt.gcf()

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 30)
p = stats.norm.pdf(x, np.mean(energies), np.std(energies))
plt.plot(x, p, 'k', linewidth=1, color="gray")
plt.show()
fig1.savefig('test_data_distribution.png', dpi = 300)
# Out:
# /tmp/ipykernel_34452/2590204840.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k" (-> color=(0.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(x, p, 'k', linewidth=1, color="gray")
